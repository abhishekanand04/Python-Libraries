# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekanand04/Python-Libraries/blob/feature/Oct24_DV_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O vgsales.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/vgsales.csv
# 100% 2.04M/2.04M [00:01<00:00, 1.72MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16652.000000  16381.000000  16652.000000  16652.000000  16652.000000
# mean    8283.409620   2006.390513      2.752314      1.996875      2.499677
# std     4794.471477      5.863261      1.327002      1.322972      1.164023
# min        1.000000   1980.000000      0.140000      0.010000      0.000000
# 25%     4129.750000   2003.000000      1.781124      1.087977      1.781124
# 50%     8273.500000   2007.000000      2.697415      1.714664      2.480356
# 75%    12436.250000   2010.000000      3.677290      2.795123      3.176299
# max    16600.000000   2020.000000      8.725452      8.367985     12.722984
#
#         Other_Sales  Global_Sales
# count  16652.000000  16652.000000
# mean       1.151829      8.457873
# std        1.054813      3.717756
# min       -0.474276      0.240000
# 25%        0.394830      5.580341
# 50%        0.491870      7.536614
# 75%        1.781124     11.227334
# ...

# %%
# How can we plot the sales trend over the years for the longest running game?

game_life = data.groupby('Name').agg(min_year = ('Year', 'min'), max_year = ('Year', 'max'))
game_life['range'] = game_life['max_year'] - game_life['min_year']
game_life.sort_values(['range'], ascending = False)[:5]
# Out:
#                                   min_year  max_year  range
# Name
# Ice Hockey                          1980.0    2020.0   40.0
# Baseball                            1980.0    2019.0   39.0
# Battlezone                          1982.0    2006.0   24.0
# Romance of the Three Kingdoms II    1991.0    2015.0   24.0
# Bomberman                           1985.0    2008.0   23.0

# %%
ih = data.loc[data['Name'] == 'Ice Hockey']
ih
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...

# %%
x_val = [0, 1, 2]
y_val = [3, 5, 9]
plt.plot(x_val, y_val)

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales')
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
sns.lineplot(data = ih, x = 'Year', y = 'Global_Sales')
# Out:
# <Axes: xlabel='Year', ylabel='Global_Sales'>

# %%
plt.title('Ice Hockey Sales Trend')
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales')
plt.ylabel('Sales')
plt.show()

# %%
plt.title('Ice Hockey Sales Trend')
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', color = 'r')
plt.ylabel('Sales')
plt.show()

# %%
plt.title('Ice Hockey Sales Trend')
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', color = 'r')
plt.ylabel('Sales')
plt.xlim(left = 1990, right = 2010)
plt.show()

# %%
baseball = data.loc[data['Name'] == 'Baseball']
baseball.head()
# Out:
#      Rank      Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 941   324  Baseball      NES  1980.0  Sports  Nintendo  0.459000  2.320000
# 942   422  Baseball      NES  1983.0  Sports  Nintendo  0.468529  2.697415
# 943   231  Baseball       GB  1985.0  Sports  Nintendo  0.473000  3.074830
# 944  1144  Baseball       GB  1989.0  Sports  Nintendo  0.478448  3.452245
# 945   134  Baseball       GB  1992.0  Sports  Nintendo  0.520000  3.829660
#
#      JP_Sales  Other_Sales  Global_Sales
# 941  5.230000     1.230000      9.239000
# 942  5.854415     1.087977     10.108336
# 943  6.478831     0.945954     10.972614
# 944  7.103246     0.803931     11.837870
# 945  7.727661     0.661908     12.739229

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales')
plt.show()

# %%
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales')
plt.show()

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales')
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales')
plt.show()

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', label = 'Ice Hockey')
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales', label = 'Baseball')
plt.show()

# %%
# upper center
# upper left
# upper right
# lower right

sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', label = 'Ice Hockey')
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales', label = 'Baseball')
plt.legend(loc = 'lower right')
plt.show()

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', label = 'Ice Hockey')
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales', label = 'Baseball')
plt.legend(loc = (-0.5, 0.5))
plt.show()

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', label = 'Ice Hockey')
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales', label = 'Baseball')
plt.legend(loc = (1, 0.5))
plt.show()

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', label = 'Ice Hockey')
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales', label = 'Baseball')
plt.legend(loc = 'lower right', ncols = 2)
plt.show()

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', label = 'Ice Hockey')
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales', label = 'Baseball')
plt.legend(loc = 'lower right', ncols = 2, frameon = False)
plt.show()

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', label = 'Ice Hockey')
sns.lineplot(data = baseball, x = 'Year', y = 'NA_Sales', label = 'Baseball')
plt.legend(loc = 'lower right', ncols = 2, frameon = False)
plt.grid()
plt.show()

# %%
sns.lineplot(data = ih, x = 'Year', y = 'NA_Sales', label = 'Ice Hockey')
sns.scatterplot(data = baseball, x = 'Year', y = 'NA_Sales', label = 'Baseball')
plt.legend(loc = 'lower right', ncols = 2, frameon = False)
plt.grid()
plt.show()

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
len(data['Rank'].value_counts())
# Out:
# 16652

# %%
len(data['Global_Sales'].value_counts())
# Out:
# 5437

# %%
sns.lineplot(data = data, x = 'Rank', y = 'Global_Sales')
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
sns.scatterplot(data = data, x = 'Rank', y = 'Global_Sales')
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
sns.scatterplot(data = data, x = 'Rank', y = 'NA_Sales')
# Out:
# <Axes: xlabel='Rank', ylabel='NA_Sales'>

# %%
sns.scatterplot(data = data, x = 'Year', y = 'NA_Sales')
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
top3_pub = data['Publisher'].value_counts().index[:3]
top3_gen = data['Genre'].value_counts().index[:3]
top3_plat = data['Platform'].value_counts().index[:3]

top3_data = data.loc[(data["Publisher"].isin(top3_pub)) & (data["Platform"].isin(top3_plat)) & (data['Genre'].isin(top3_gen))]
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data['Platform'].value_counts()
# Out:
# Platform
# DS      2163
# PS2     2161
# PS3     1330
# Wii     1327
# X360    1267
# PSP     1213
# PS      1204
# PC       969
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      338
# N64      319
# SNES     251
# XOne     213
# SAT      173
# 2600     144
# WiiU     143
# GB       102
# NES       99
# DC        52
# GEN       27
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# X361       1
# X362       1
# PCFX       1
# GG         1
# Name: count, dtype: int64

# %%
data['Platform'].value_counts().index
# Out:
# Index(['DS', 'PS2', 'PS3', 'Wii', 'X360', 'PSP', 'PS', 'PC', 'XB', 'GBA', 'GC',
#        '3DS', 'PSV', 'PS4', 'N64', 'SNES', 'XOne', 'SAT', '2600', 'WiiU', 'GB',
#        'NES', 'DC', 'GEN', 'NG', 'WS', 'SCD', '3DO', 'TG16', 'X361', 'X362',
#        'PCFX', 'GG'],
#       dtype='object', name='Platform')

# %%
# How can we compare the top 3 platforms these publishers use?
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
sns.countplot(x='Publisher', data = top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %%
sns.countplot(x='Publisher', hue = 'Platform', data = top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %%
df_stacked_plot = pd.crosstab(index=top3_data['Publisher'], columns=top3_data['Platform'])
df_stacked_plot
# Out:
# Platform            DS  PS2  PS3
# Publisher
# Activision          66   65   63
# Electronic Arts     38  127   98
# Namco Bandai Games  70   39   51

# %%
df_stacked_plot.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Activision'),
#   Text(1, 0, 'Electronic Arts'),
#   Text(2, 0, 'Namco Bandai Games')])

# %%
sns.boxplot(data['Global_Sales'])
# Out:
# <Axes: ylabel='Global_Sales'>

# %%
sns.boxplot(data = top3_data, x = 'Publisher', y = 'Global_Sales')
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.boxplot(data = top3_data, x = 'Publisher', y = 'Global_Sales')
plt.xticks(rotation = 45)
plt.show()

# %%
sns.barplot(data = top3_data, x = 'Publisher', y = 'Global_Sales')
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.barplot(data = top3_data, x = 'Publisher', y = 'Global_Sales', estimator = 'max')
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.barplot(data = top3_data, x = 'Publisher', y = 'Global_Sales', estimator = 'min')
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
top3_data.head()
# Find the trend of NA_Sales wrt all other type of sales.
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['EU_Sales'])
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['JP_Sales'])
# Out:
# <Axes: xlabel='NA_Sales', ylabel='JP_Sales'>

# %%
plt.figure(figsize = (12, 8))

plt.subplot(2, 2, 1)
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['EU_Sales'])

plt.subplot(2, 2, 2)
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['JP_Sales'])

plt.subplot(2, 2, 3)
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['Other_Sales'])

plt.subplot(2, 2, 4)
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['Global_Sales'])
# Out:
# <Axes: xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
fig, ax = plt.subplots(2, 2, figsize = (12, 8))

ax[0, 0].scatter(x=top3_data['NA_Sales'], y=top3_data['EU_Sales'])
ax[0, 1].scatter(x=top3_data['NA_Sales'], y=top3_data['JP_Sales'])
ax[1, 0].scatter(x=top3_data['NA_Sales'], y=top3_data['Other_Sales'])
ax[1, 1].scatter(x=top3_data['NA_Sales'], y=top3_data['Global_Sales'])

# %%
plt.figure(figsize = (9, 6))

plt.subplot(2, 2, 1)
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['EU_Sales'])

plt.subplot(2, 2, 3)
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['Other_Sales'])

plt.subplot(1, 2, 2)
sns.scatterplot(x=top3_data['NA_Sales'], y=top3_data['Global_Sales'])
# Out:
# <Axes: xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
data.loc[data["Name"] == "Ice Hockey"]
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...

# %%
data[data["Name"] == "Ice Hockey"]
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...
