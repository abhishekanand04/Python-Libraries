# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekanand04/Python-Libraries/blob/feature/Oct24_DV_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O final_vg.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/final_vg.csv
# 100% 2.04M/2.04M [00:00<00:00, 10.1MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('final_vg.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
top3_pub = data['Publisher'].value_counts().index[:3]
top3_gen = data['Genre'].value_counts().index[:3]
top3_plat = data['Platform'].value_counts().index[:3]
top3_data = data.loc[(data["Publisher"].isin(top3_pub)) & (data["Platform"].isin(top3_plat)) & (data['Genre'].isin(top3_gen))]
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# How can we visualize the correlation between NA_Sales and EU_Sales, but for different genres?

# NA_Sales -> Numerical
# EU_Sales -> Numerical
# Genres -> Categorical

# NNC

# %%
# NN -> Add cat data  (YES)
# NC -> Add num data  - X

# %%
# NC -> Box plot -> Can we add numeric data in it?
sns.boxplot(data = top3_data, x = 'Publisher', y = 'Global_Sales')
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.barplot(data = top3_data, x = 'Publisher', y = 'Global_Sales')
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.scatterplot(x = 'NA_Sales', y = 'EU_Sales', data = top3_data)
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
sns.scatterplot(x = 'NA_Sales', y = 'EU_Sales', hue ='Genre', data = top3_data)
plt.title('NA vs EU, per Genre', fontsize=15)
plt.show()

# %%
# How will you visualize the global sales for each publisher, but separated by genres?

# Global Sales -> N
# Publisher -> C
# Genre -> C

# NC -> C (YES)
# CC -> N

# %%
sns.boxplot(x = 'Publisher', y = 'Global_Sales', data = top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.boxplot(x = 'Publisher', y = 'Global_Sales', hue ='Genre', data = top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %%
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
len(top3_data['Rank'].value_counts())
# Out:
# 617

# %%
# How does rank affect the correlation between NA and EU Sales?

# Rank  -> N
# NA_Sales -> N
# EU_Sales -> N

# %%
sns.scatterplot(x = 'NA_Sales', y = 'EU_Sales', data = top3_data)
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
sns.scatterplot(x = 'NA_Sales', y = 'EU_Sales', hue = 'Rank', data = top3_data)
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
sns.scatterplot(x = 'NA_Sales', y = 'EU_Sales', size = 'Rank', sizes = (1, 200), data = top3_data)
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
sns.scatterplot(x = 'Rank', y = 'EU_Sales', size = 'NA_Sales', sizes = (1, 200), data = top3_data)
# Out:
# <Axes: xlabel='Rank', ylabel='EU_Sales'>

# %%
sns.jointplot(x = 'NA_Sales', y = 'EU_Sales', data = top3_data)

# %%
# We can select from different values for parameter `kind and it will plot accordingly.
# "scatter" | "kde" | "hist" | "hex" | "reg" | "resid"

sns.jointplot(x = 'NA_Sales', y = 'EU_Sales', kind = 'reg', data = top3_data)

# %%
sns.jointplot(x = 'NA_Sales', y = 'EU_Sales', kind = 'hex', data = top3_data)

# %%
sns.jointplot(x = 'NA_Sales', y = 'EU_Sales', kind = 'kde', data = top3_data)

# %%
sns.jointplot(x = 'NA_Sales', y = 'EU_Sales', hue ='Genre', data = top3_data)

# %%
top3_data.head()
# Out:
#      Rank                               Name Platform    Year   Genre  \
# 2   14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0  Action
# 13   2742                      [Prototype 2]      PS3  2012.0  Action
# 16   1604                        [Prototype]      PS3  2009.0  Action
# 19   1741             007: Quantum of Solace      PS3  2008.0  Action
# 21   4501             007: Quantum of Solace      PS2  2008.0  Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2   Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13          Activision  3.978349  3.727034  0.848807     2.792725
# 16          Activision  4.569217  4.108402  1.187272     3.339269
# 19          Activision  4.156030  4.346074  1.087977     3.390562
# 21          Activision  3.228043  2.738800  2.585598     3.652926
#
#     Global_Sales
# 2       4.982552
# 13     11.447989
# 16     13.181205
# 19     12.980643
# 21     11.780257

# %%
# Analyse all numeric data and check if there is any correlation.
sns.pairplot(top3_data)

# %%
sns.pairplot(top3_data, hue = 'Genre')

# %%
sns.pairplot(top3_data, vars =['NA_Sales', 'EU_Sales', 'JP_Sales'], hue = 'Genre')

# %%
sns.pairplot(top3_data, x_vars =['NA_Sales', 'EU_Sales'], y_vars = ['JP_Sales', 'Global_Sales'], hue = 'Genre')

# %%
num_df = top3_data.select_dtypes(include=[float,int])
num_df.head()
# Out:
#      Rank    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 2   14279  2012.0  1.145709  1.762339  1.493442     0.408693      4.982552
# 13   2742  2012.0  3.978349  3.727034  0.848807     2.792725     11.447989
# 16   1604  2009.0  4.569217  4.108402  1.187272     3.339269     13.181205
# 19   1741  2008.0  4.156030  4.346074  1.087977     3.390562     12.980643
# 21   4501  2008.0  3.228043  2.738800  2.585598     3.652926     11.780257

# %%
# + means increase in value of one variable causes increase in value of other variable.
# - means increase in value of one variable causes decrease in value of other variable, and vice versa.
num_df.corr()
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.328705 -0.873726 -0.735711  0.115459    -0.857567
# Year          0.328705  1.000000 -0.354256 -0.178026  0.055864    -0.239876
# NA_Sales     -0.873726 -0.354256  1.000000  0.617483 -0.233315     0.794353
# EU_Sales     -0.735711 -0.178026  0.617483  1.000000 -0.208249     0.771105
# JP_Sales      0.115459  0.055864 -0.233315 -0.208249  1.000000    -0.355825
# Other_Sales  -0.857567 -0.239876  0.794353  0.771105 -0.355825     1.000000
# Global_Sales -0.911721 -0.280351  0.856300  0.864147 -0.014193     0.878816
#
#               Global_Sales
# Rank             -0.911721
# Year             -0.280351
# NA_Sales          0.856300
# EU_Sales          0.864147
# JP_Sales         -0.014193
# Other_Sales       0.878816
# Global_Sales      1.000000

# %%
sns.scatterplot(x = 'Rank', y = 'Global_Sales', data = top3_data)
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
sns.heatmap(num_df.corr(), cmap= "Blues", annot=True)
plt.show()

# %%
sns.heatmap(num_df.corr(), cmap= "Blues")
plt.show()

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r',
# ...

# %%
sns.heatmap(num_df.corr(), cmap= "inferno", annot=True)
plt.show()

# %%
sns.heatmap(num_df.corr(), cmap= "OrRd", annot=True)
plt.show()

# %%
data = {
    'Country': ['USA', 'China', 'Japan', 'Germany'],
    'Gold': [30, 35, 20, 25],
    'Silver': [20, 25, 15, 18],
    'Bronze': [15, 20, 10, 12]
}

df = pd.DataFrame(data)

# Melt the DataFrame to long format for easier plotting
df_melted = df.melt(id_vars='Country', var_name='Medal', value_name='Count')

df_melted
# Out:
#     Country   Medal  Count
# 0       USA    Gold     30
# 1     China    Gold     35
# 2     Japan    Gold     20
# 3   Germany    Gold     25
# 4       USA  Silver     20
# 5     China  Silver     25
# 6     Japan  Silver     15
# 7   Germany  Silver     18
# 8       USA  Bronze     15
# 9     China  Bronze     20
# 10    Japan  Bronze     10
# 11  Germany  Bronze     12

# %%
# We are analyzing the results of the Olympics, and want to find the count of gold,
# silver, and bronze medals won by each country. Which will be the best suited plot for this?

sns.barplot(x = 'Country', y = 'Count', hue = 'Medal', data = df_melted)
# Out:
# <Axes: xlabel='Country', ylabel='Count'>

# %%
plt.figure(figsize=(12, 6))

# Subplot spanning the entire first row (1st to 3rd index)
plt.subplot(2, 3, (1, 3))
plt.title('This subplot spans the first row')
plt.plot([1, 2, 3], [4, 5, 6], marker='o')

# Create individual subplots for the remaining cells
plt.subplot(2, 3, 4)
plt.title('2nd Row, 1st Column')
plt.plot([1, 2], [4, 5], marker='x')

plt.subplot(2, 3, 5)
plt.title('2nd Row, 2nd Column')
plt.plot([1, 2], [2, 4], marker='s')

plt.subplot(2, 3, 6)
plt.title('2nd Row, 3rd Column')
plt.plot([1, 2], [3, 6], marker='d')

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()
